# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set_theme()

# %%
# import dataset
data = pd.read_csv('cleaned_car_data.csv')
data.head()
# Out:
#              name manufacturer  year  age  mileage  engine transmission  price
# 0       Mazda MX5        Mazda  2007   14    63131  Petrol       Manual   7499
# 1       Jaguar XF       Jaguar  2010   11    61890  Petrol    Automatic   7775
# 2         Audi A6         Audi  2012    9   129170  Diesel    Automatic   6950
# 3  Nissan Qashqai       Nissan  2013    8    44900  Petrol    Automatic   7790
# 4       MINI Mini         Mini  2017    4    32012  Petrol       Manual  15999

# %% [markdown]
# ## Data Analysis

# %%
#the most expensive cars in the collection
data.nlargest(5, 'price')
# Out:
#                      name   manufacturer  year  age  mileage          engine  \
# 780          BMW 7 Series            BMW  2017    4    64828  Plug_in_hybrid
# 2931  Ford Transit Custom           Ford  2021    0      891          Diesel
# 2935         Ford Transit           Ford  2021    0      176          Diesel
# 2984         Ford Transit           Ford  2020    1    12355          Diesel
# 2540    Mercedes-Benz GLC  Mercedes-Benz  2017    4    38334          Diesel
#
#        transmission  price
# 780       Automatic  30000
# 2931         Manual  30000
# 2935         Manual  30000
# 2984         Manual  30000
# 2540  Semiautomatic  29999

# %%
#cars with the most miles in the collection
data.nlargest(5, 'mileage')
# Out:
#                name manufacturer  year  age  mileage  engine transmission  \
# 1190  Volkswagen CC   Volkswagen  2012    9   184500  Diesel       Manual
# 1192  Volkswagen CC   Volkswagen  2011   10   176000  Diesel    Automatic
# 1297  Nissan Navara       Nissan  2006   15   175000  Diesel       Manual
# 8      Toyota Prius       Toyota  2013    8   172000  Hybrid    Automatic
# 1916        Audi A6         Audi  2010   11   171175  Diesel    Automatic
#
#       price
# 1190   3095
# 1192   3990
# 1297   4550
# 8      6290
# 1916   3490

# %%
#oldest cars in the collection
data.nlargest(5, 'age')
# Out:
#                           name manufacturer  year  age  mileage  engine  \
# 1896  Volkswagen T6 Camper Van   Volkswagen  1973   48    70000  Petrol
# 704                 Jaguar Xk8       Jaguar  1997   24    66000  Petrol
# 1965      Land Rover Discovery   Land-Rover  2000   21   107600  Diesel
# 1273           Porsche Cayenne      Porsche  2004   17    83000  Petrol
# 1640              NISSAN 350 Z       Nissan  2004   17   112000  Petrol
#
#      transmission  price
# 1896       Manual  19995
# 704     Automatic   8985
# 1965    Automatic   3895
# 1273    Automatic   4990
# 1640       Manual  10000

# %%
#drop the year column
data = data.drop('year', axis=1)

# %%
data.head()
# Out:
#              name manufacturer  age  mileage  engine transmission  price
# 0       Mazda MX5        Mazda   14    63131  Petrol       Manual   7499
# 1       Jaguar XF       Jaguar   11    61890  Petrol    Automatic   7775
# 2         Audi A6         Audi    9   129170  Diesel    Automatic   6950
# 3  Nissan Qashqai       Nissan    8    44900  Petrol    Automatic   7790
# 4       MINI Mini         Mini    4    32012  Petrol       Manual  15999

# %%
corr = data.corr()
corr
# Out:
#               age   mileage     price
# age      1.000000  0.721596 -0.642909
# mileage  0.721596  1.000000 -0.534742
# price   -0.642909 -0.534742  1.000000

# %%
# heat map
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns, annot=True);

# %%
# count of cars by car make
fig = plt.figure(figsize=(20, 10))
sns.countplot(data.manufacturer);
plt.title("Distribution of car manufacturers")
plt.xticks(rotation=90)
plt.savefig('distribution-of-car-make.png')

# %% [markdown]
# # Categorical variable
# data.make.value_counts()
